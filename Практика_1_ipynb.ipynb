# %% [markdown]
# <a href="https://colab.research.google.com/github/luci4-4/ML/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_1_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # МЛ Практика 1
# ## Обзор занятий: Чем предстоит заниматься
# Цели сессии:
#
# 1. Ознакомление с основными понятиями машинного обучения и структурой практических занятий.
# 2. Представление доступных наборов данных для последующих упражнений.
# 3. Формирование списка участников и распределение ролей (при необходимости).
# 4. Практическое освоение методов описательного анализа данных.
# 5. Понимание типов данных и их важности в контексте машинного обучения.
# План занятий:
#
# 1. Введение и обзор целей курса.
# 2. Представление наборов данных.
# 3. Формирование списка студентов.
# 4. Совместный разбор выбранного набора данных с обсуждением вопросов.
# 5. Задача 1: Описание набора данных и определение типов данных.
# 6. Пример статистического разбора на основе wine.csv.
# 7. Обсуждение типов переменных и их определения по статистике.
# 8. Вопросы и ответы, обсуждение домашних заданий.

# %% [markdown]
# # Наборы данных по вариантам

# %% [markdown]
# Примеры наборов данных

# %% [markdown]
# 1. https://www.kaggle.com/datasets/nabeelqureshitiii/student-performance-dataset
# 2. https://www.kaggle.com/datasets/navjotkaushal/coffee-sales-dataset
# 3. https://www.kaggle.com/datasets/shamimhasan8/education-inequality-data
# 4. https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset
# 5. https://www.kaggle.com/datasets/navjotkaushal/employees-dataset
# 6. https://www.kaggle.com/datasets/abolfazlchanbary81/hearth
# 7. https://www.kaggle.com/datasets/uciml/student-alcohol-consumption
# 8. https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# 9. https://www.kaggle.com/datasets/lainguyn123/student-performance-factors
# 10. https://www.kaggle.com/datasets/benroshan/factors-affecting-campus-placement
# 11. https://www.kaggle.com/datasets/datascientistanna/customers-dataset

# %% [markdown]
# ## Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
# установка зависимостей
# !pip install pandas matplotlib seaborn

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
PATH_TO_FILE: str = '/content/sample_data/Customers.csv' # Загрузка набора данных
## p.s. в левой панеле нажать на папку и перетащить туда файл,
## а wince.csv заменить на свой вариант (ПКМ -> копировать путь)

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
# Вывод первых 5 строк
df.head()

# вывод 5 последних строк
#df.tail()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
# Информация о наборе данных
df.info() # инфо о датасете название колонки, сколько не пропущенных, дефолтный тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %%
# Статистический разбор
df.describe() # include=all (вывод включая категориальные)
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %%
# преобразование в категориальные
# df.columnName = df.columnName.astype('category')
# or
# df['column Name'] = df['column Name'].astype('category')

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income ($)',
#        'Spending Score (1-100)', 'Profession', 'Work Experience',
#        'Family Size'],
#       dtype='object')

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income ($)          int64
# Spending Score (1-100)     int64
# Profession                object
# Work Experience            int64
# Family Size                int64
# dtype: object

# %% [markdown]
# - Числовые переменные обычно имеют тип int64 или float64.
# - Категориальные переменные могут иметь тип object или int (например метки класса)

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# CustomerID: 2000 уникальных значений
# Gender: 2 уникальных значений
# Age: 100 уникальных значений
# Annual Income ($): 1786 уникальных значений
# Spending Score (1-100): 101 уникальных значений
# Profession: 9 уникальных значений
# Work Experience: 18 уникальных значений
# Family Size: 9 уникальных значений

# %% [markdown]
# **⏰ задача**
#
# Определить типы переменных
# - номинальные переменные (не имеют порядка и сравнения)
# - порядковые пиеременные (имеют порядок, но не имеют смысла мат операции)
# - числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
#
# Вывести статистику для числовых и для категоиральных перменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему

# %% [markdown]
# **Ответ**:
# - Номинальные:
#   - CustomerID(id не имеют смысла к мат операциям)
#   - Gender(Два константных значений без порядка)
#   - Profession(категории без порядка)
# - Числовые непрерывнные:
#   - Age(числовое значение, есть смысл проводить математические операции)
#   - Annual Income(числовое значение, есть смысл проводить математические операции )
#   - Work Experience(числовое значение, есть смысл проводить математические операции)
#   - Family Size(числовое значение, есть смысл проводить математические операции)
#
# Гипотезы:
#   - Spending Score.
#     - Порядковая
#     - Числовая
#
# Здесь не уверен, так как не известно по какому принципу заполнялись эти значения. Если балл выставлялся человеком или на основе опроса, то это значение порядковое, если заполнялось автоматически по какой-нибудь формуле, то это числовая непрерывная и это уже можно использовать в анализе.

# %% [markdown]
# Числовые переменные:

# %%
df_numberic = df.select_dtypes(include=['number'])

df_numberic.describe()
# Out:
#         CustomerID          Age  Annual Income ($)  Spending Score (1-100)  \
# count  2000.000000  2000.000000        2000.000000             2000.000000
# mean   1000.500000    48.960000      110731.821500               50.962500
# std     577.494589    28.429747       45739.536688               27.934661
# min       1.000000     0.000000           0.000000                0.000000
# 25%     500.750000    25.000000       74572.000000               28.000000
# 50%    1000.500000    48.000000      110045.000000               50.000000
# 75%    1500.250000    73.000000      149092.750000               75.000000
# max    2000.000000    99.000000      189974.000000              100.000000
#
#        Work Experience  Family Size
# count      2000.000000  2000.000000
# mean          4.102500     3.768500
# std           3.922204     1.970749
# min           0.000000     1.000000
# 25%           1.000000     2.000000
# 50%           3.000000     4.000000
# ...

# %% [markdown]
# Категориальные переменные:

# %%
df_categorical = df.select_dtypes(include=['object', 'category'])

for col in df_categorical.columns:
    print(f'\n{col}:')
    print(df_categorical[col].value_counts())
    print('Уникальных значений:', df_categorical[col].nunique())
# Out:
# Gender:
# Gender
# Female    1186
# Male       814
# Name: count, dtype: int64
# Уникальных значений: 2
#
# Profession:
# Profession
# Artist           612
# Healthcare       339
# Entertainment    234
# Engineer         179
# Doctor           161
# Executive        153
# Lawyer           142
# Marketing         85
# Homemaker         60
# Name: count, dtype: int64
# Уникальных значений: 9

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовых переменных:**

# %%
positiveForAnalizeField = [
    'Age',
    'Annual Income ($)',
    'Spending Score (1-100)',
    'Work Experience',
    'Family Size'
]

fig, axes = plt.subplots(1, len(positiveForAnalizeField), figsize=(6 * len(positiveForAnalizeField), 4))

for ax, col in zip(axes, positiveForAnalizeField):
   sns.histplot(df[col], kde=True, ax=ax)
   ax.set_title(f'Распределение {col}')
   ax.set_xlabel(col)
   ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Является ли распределение нормальным или отлично от него?
# - Концентрация большинства значений
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
#
# p.s. 3-5 самых показательных примеров.

# %% [markdown]
# **Ответ**
#
# - Age (Возраст)
#
#     Распределение: Значения возраста распределены довольно равномерно по всей шкале (0-100), небольшое смещение влево — чуть больше клиентов в диапазоне 20-40 лет.
#
#     Нормальность: Нет выраженного нормального распределения (характерной колоколообразной формы). Видна некоторая "полуплоская" структура.
#
#     Концентрация: Большинство значений — в диапазоне 20-60 лет.
#
# - Annual Income ($) (Годовой доход)
#
#     Распределение: Ближе к симметричному или колоколообразному, но в центральной части наблюдается повышенная концентрация. Увеличение и уменьшение частоты неравномерны.
#
#     Нормальность: Распределение ближе к нормальному, но левая часть немного шире, чем правая; видны выбросы (небольшое количество очень больших или очень маленьких доходов).
#
#     Концентрация: Основная масса значений располагается в районе 70,000 - 140,000 долларов.
#
# - Spending Score (1-100) (Потребительский балл)
#
#     Распределение: Близко к равномерному — почти все баллы встречаются с похожей частотой, выраженного пика нет.
#
#     Нормальность: Далеко от нормального распределения. Видно много разных значений с похожей частотой, без явного центра.
#
#     Концентрация: Нет выраженной зоны концентрации — баллы распределены примерно равномерно по всей шкале.
#
# - Work Experience (Опыт работы)
#
#     Распределение: Явно асимметричное — сильный пик на 0–2 годах, затем убывание. Видно длинный правый хвост (немного клиентов с бóльшим опытом работы).
#
#     Нормальность: Нет; отчетливо выраженная асимметрия.
#
#     Концентрация: Большинство клиентов имеет опыт работы 0–3 года.
#
# - Family Size (Размер семьи)
#
#     Распределение: Мульти-модальное (несколько пиков), основная масса — небольшая семья (1–4 человека), далее частота быстро падает.
#
#     Нормальность: Распределение не является нормальным; сильно смещено к меньшим размерам семьи.
#
#     Концентрация: Основная часть данных находится до 4–5 человек в семье.

# %% [markdown]
# 2. **Столбчатая диаграмма для категориальной переменной `Class`:**

# %%
# sns.countplot(x='quality', data=df)
# plt.title('Распределение quality')
# plt.xlabel('quality')
# plt.ylabel('Количество')
# plt.show()

# ниже код для оптимизации вывода всех категориальных переменных
num_cols = df.select_dtypes(include='object').columns # или object
fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

for ax, col in zip(axes, num_cols):
   sns.histplot(df[col], kde=True, ax=ax)
   ax.set_title(f'Распределение {col}')
   ax.set_xlabel(col)
   ax.set_ylabel('Частота')
   for label in ax.get_xticklabels():
        label.set_rotation(40)

plt.tight_layout()
plt.show()

# %% [markdown]
# Можно ли использовать Spending Score для определения пола?

# %%
# sns.histplot(data=df, x="Spending Score (1-100)", hue="Gender", kde=True, multiple="stack")
sns.histplot(data=df, x="Spending Score (1-100)", hue="Gender", kde=True, stat="density", common_norm=False)

plt.show()

# %% [markdown]
# Вывод- нет, нельзя. Распределение выглядит идентичным для обоих полов. Нет мест где есть большие просадки по полу.

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - в каких значениях концентрируентся переменная?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)

# %% [markdown]
# **Боксплот для числовой переменной:**

# %%
positiveForAnalizeField = [
    'Age',
    'Annual Income ($)',
    'Spending Score (1-100)',
    'Work Experience',
    'Family Size'
]

fig, axes = plt.subplots(1, len(positiveForAnalizeField), figsize=(6 * len(positiveForAnalizeField), 4))

for ax, col in zip(axes, positiveForAnalizeField):
   sns.boxplot(df[col], ax=ax)
   ax.set_title(f'Распределение {col}')
   ax.set_xlabel(col)
   ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ответ**
#
# - Age (возраст)
#
#     Медиана: примерно 50 лет.
#
#     Ящик (25%–75%): от 25 до 75 лет.
#
#     Усы: от 0 до 100.
#
#     Концентрация: основная часть клиентов — 25–75 лет, медиана ровно посередине, а значит структура близка к равномерной.
#
# - Annual Income ($) (годовой доход)
#
#     Медиана: примерно $110,000.
#
#     Ящик (25%–75%): примерно от $75,000 до $150,000.
#
#     Усы: от $0 до $190,000.
#
#     Концентрация: львиная доля клиентов получает от $75,000 до $150,000 в год, а медиана находится примерно посередине этого диапазона.
#
# - Spending Score (1-100)
#
#     Медиана (линия внутри ящика): около 50.
#
#     Ящик (25%–75%): основной «клубок» значений лежит, примерно, между 25 и 75.
#
#     Усы (минимум и максимум без выбросов): примерно от 0 до 100. Практически все значения равномерно распределены по всей шкале.
#
#     Концентрация: большинство значений — в диапазоне 25–75. Там находится 50% всех клиентов. Очень экстремальных значений мало.
#
# - Work Experience
#
#     Медиана: примерно 2–3 года (линия внутри ящика).
#
#     Ящик (25%–75%): значения от примерно 1 до 7 лет.
#
#     Усы: до 15–17 лет; есть отдельные выбросы выше основного диапазона.
#
#     Концентрация: основная масса (50%) находится между 1 и 7 годами опыта, но больше всего значений сосредоточено в районе 1–3 лет (это видно по сжатию нижней части ящика и медиане).
#
#     Есть выбросы: отдельные клиенты с особенно большим опытом (рядом с верхней «усом»).
#
# - Family Size (размер семьи)
#
#     Медиана: 4 человека.
#
#     Ящик (25%–75%): от 2 до 5 человек.
#
#     Усы: от 1 до 9 человек.
#
#     Концентрация: большая часть клиентов имеют 2–5 человек в семье, самый массовый размер — 4 человека.

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Есть ли выбросы?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина). Определить различия по медиане

# %% [markdown]
# **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %%
# Корреляционная матрица
correlation_matrix = df.drop(columns=['CustomerID']).corr()

# Визуализация тепловой карты
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица')
plt.show()

# %% [markdown]
# **Ответ**
# есть ли выбросы:
# Если судить по коррелиционной матрице, их не видно, но как я отметил выше, они наблюдаются в work experience.
#
# На коррелиционной матрице видно, что почти нигде нет линейнной связи, все находится в пределах 0.04 - 0.09, то есть все переменные плохо предсказывают друг друга.

# %%
sns.boxplot(data=df, x="Gender", y="Spending Score (1-100)")
plt.title("Spending Score по полу")
plt.show()

# %% [markdown]
# Как и описывал выше, нельзя определить пол по Spending Score. Графики почти полностью совпадают друг с другом(у женщин медиана на 1-3 меньше чем у мужчин)

# %% [markdown]
# **если ValueError**

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('Profession', axis=1)
df = df.drop('Gender', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()

# %% [markdown]
# **задача ⏰**
#
# Интерпертировать полученный результат:
# - Какие переменные не коррелируют?
# - Какие переменные имеют сильную положительную корреляцию?
# - Какие переменные имеют сильную слабую корреляцию?
#
# p.s. сильная корреляция считаем abs(corr_coef) >= 0.7

# %% [markdown]
# **Ответ**
#
# Все переменные имеют крайне слабую корреляцию
